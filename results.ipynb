# %%
import pandas as pd

# %%
df = pd.read_csv("results.csv")
df.head()
# Out:
#    Run  Case Dimensions  Naive Time (s)  Blocked Time (s)  Parallel Time (s)  \
# 0    1     0   64x64x64        0.001949          0.002631           0.001822
# 1    2     0   64x64x64        0.001724          0.002879           0.001871
# 2    3     0   64x64x64        0.001928          0.002636           0.002292
# 3    4     0   64x64x64        0.001748          0.003492           0.002110
# 4    5     0   64x64x64        0.001753          0.004113           0.001760
#
#    Blocked Speedup (x)  Parallel Speedup (x)
# 0             0.740849              1.069470
# 1             0.598909              0.921552
# 2             0.731315              0.841159
# 3             0.500644              0.828429
# 4             0.426120              0.996022

# %%
df.drop(columns=['Dimensions', 'Run'], inplace=True)

# %%
df.groupby(['Case']).mean()
# Out:
#       Naive Time (s)  Blocked Time (s)  Parallel Time (s)  \
# Case
# 0           0.001820          0.003150           0.001971
# 1           0.007134          0.012213           0.006315
# 2           0.004972          0.007658           0.004033
# 3           0.007388          0.011238           0.006139
# 4           0.000872          0.001411           0.001214
# 5           0.035313          0.056534           0.028929
# 6           0.118653          0.178597           0.098928
# 7           0.138863          0.207555           0.118014
# 8           0.003496          0.005769           0.003319
# 9           0.120380          0.179924           0.107247
#
#       Blocked Speedup (x)  Parallel Speedup (x)
# Case
# 0                0.599567              0.931326
# 1                0.596648              1.146395
# 2                0.651309              1.238676
# 3                0.658061              1.215646
# 4                0.625580              0.726979
# ...
